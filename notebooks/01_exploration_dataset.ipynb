# %%
import sys
import os

sys.path.append(r"C:\EPF\IA\Tumor_Detection_Project\tumor-detection")   
import matplotlib.pyplot as plt
from src.datasets.mri_dataset import MRIDataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 from src.datasets.mri_dataset import MRIDataset
#
# ModuleNotFoundError: No module named 'src'

# %%
dataset = MRIDataset("data/raw/Training")

print(f"Nombre d'images : {len(dataset)}")

# %%
fig, axes = plt.subplots(2, 4, figsize=(12, 6))

for i, ax in enumerate(axes.flatten()):
    img, label = dataset[i]
    ax.imshow(img)
    ax.set_title(f"Label: {label}")
    ax.axis("off")

plt.show()
